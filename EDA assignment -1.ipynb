# %%
# reading the csv file 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
path=r"C:\Users\rakes\naresh it data  science (adi)\Data files\bank - bank.csv"
pd.read_csv(path)
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
pd.read_csv(path,sep=";")
# Out:
#      age,job,marital,education,default,balance,housing,loan,contact,day,month,duration,campaign,pdays,previous,poutcome,y
# 0     30,unemployed,married,primary,no,1787,no,no,ce...
# 1     33,services,married,secondary,no,4789,yes,yes,...
# 2     35,management,single,tertiary,no,1350,yes,no,c...
# 3     30,management,married,tertiary,no,1476,yes,yes...
# 4     59,blue-collar,married,secondary,no,0,yes,no,u...
# ...                                                 ...
# 4516  33,services,married,secondary,no,-333,yes,no,c...
# 4517  57,self-employed,married,tertiary,yes,-3313,ye...
# 4518  57,technician,married,secondary,no,295,no,no,c...
# 4519  28,blue-collar,married,secondary,no,1137,no,no...
# 4520  44,entrepreneur,single,tertiary,no,1136,yes,ye...
#
# [4521 rows x 1 columns]

# %%
# create dataframes using list 
name=['ramesh','suresh','satish']
age=[30,35,40]
name,age
# Out:
# (['ramesh', 'suresh', 'satish'], [30, 35, 40])

# %%
pd.DataFrame(zip(name,age))
# Out:
#         0   1
# 0  ramesh  30
# 1  suresh  35
# 2  satish  40

# %%
# provide coloumns 
data=zip(name,age)
cols=['name','age']
d1=pd.DataFrame(data,columns=cols)
d1
# Out:
#      name  age
# 0  ramesh   30
# 1  suresh   35
# 2  satish   40

# %%
name=['ramesh','suresh','satish']
age=[30,35,40]
data=zip(name,age)
cols=['Name','Age']
index=['A','B','C']
df=pd.DataFrame(data,columns=cols,index=ind)
df
# Out:
#      Name  Age
# a  ramesh   30
# b  suresh   35
# c  satish   40

# %%
#add new column
city_names=["hyd","blr",'chennai']
df["city"]=city_names
df
# Out:
#      Name  Age     city
# a  ramesh   30      hyd
# b  suresh   35      blr
# c  satish   40  chennai

# %%
# update the existing column
df['Name']=['swamy','asif','sathwik']
df
# Out:
#       Name  Age     city
# a    swamy   30      hyd
# b     asif   35      blr
# c  sathwik   40  chennai

# %%
# DROP THE COLUMN 
df.drop('city',axis=1,inplace=True)
df
# Out:
#       Name  Age
# a    swamy   30
# b     asif   35
# c  sathwik   40

# %%
# drop rows
df.drop('c',axis=0,inplace=True)
df
# Out:
#     Name  Age
# a  swamy   30
# b   asif   35

# %%
#save the data frame
df.to_csv('output1.csv')

# %%
pd.read_csv('output1.csv')
# Out:
#   Unnamed: 0   Name  Age
# 0          a  swamy   30
# 1          b   asif   35

# %%
# remove the index
# TO avoid problem give index=False
df.to_csv("output1.csv",index=False)

# %%
pd.read_csv('output1.csv')
# Out:
#     Name  Age
# 0  swamy   30
# 1   asif   35

# %%
# create dataframes using dicitionary 
d1={'name':['ramesh','suresh','satish'],'age':[30,35,40]}
d2=pd.DataFrame(d1)

# %%
d2['name2']=['asif','adi','piyush']
d2
# Out:
#      name  age    city   name2
# 0  ramesh   30    asif    asif
# 1  suresh   35     adi     adi
# 2  satish   40  piyush  piyush
